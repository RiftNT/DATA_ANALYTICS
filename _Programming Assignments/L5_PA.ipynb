# %%
from ucimlrepo import fetch_ucirepo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# fetch dataset 
stock_portfolio = fetch_ucirepo(id=390) 
  
df = pd.read_csv(stock_portfolio.metadata.data_url)

df
# Out:
#     period  ID  Large B/P  Large ROE  Large S/P  \
# 0      all   1      1.000      0.000      0.000
# 1      all   2      0.000      1.000      0.000
# 2      all   3      0.000      0.000      1.000
# 3      all   4      0.000      0.000      0.000
# 4      all   5      0.000      0.000      0.000
# ..     ...  ..        ...        ...        ...
# 310      4  59      0.200      0.200      0.200
# 311      4  60      0.200      0.200      0.000
# 312      4  61      0.200      0.000      0.200
# 313      4  62      0.000      0.200      0.200
# 314      4  63      0.167      0.167      0.167
#
#      Large Return Rate in the last quarter  Large Market Value  \
# 0                                    0.000               0.000
# 1                                    0.000               0.000
# 2                                    0.000               0.000
# 3                                    1.000               0.000
# 4                                    0.000               1.000
# ...

# %%
sns.scatterplot(x='Total Risk.1',y='Systematic Risk',data=df)
# Out:
# <Axes: xlabel='Total Risk.1', ylabel='Systematic Risk'>

# %%
sns.regplot(x='Total Risk.1',y='Systematic Risk',data=df)
# Out:
# <Axes: xlabel='Total Risk.1', ylabel='Systematic Risk'>
